# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,(50))
print(x)
# Out:
# [40 47 47 46 45 18 39 22 44 24 22 57 11 30 26 28 29 39 26 58 28 11 52 25
#  30 43 37 55 26 14 16 37 59 42 44 20 37 36 47 37 16 34 38 25 16 12 48 41
#  21 24]

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no)

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r")

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,200),edgecolor="r")

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",cumulative=-1)
#plt.hist(no,color="g",bins=l,edgecolor="r",bottom=20)
#plt.hist(no,color="g",bins=l,edgecolor="r",align="mid")
plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r",histtype="step")

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r",orientation="horizontal")

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r",rwidth=0.8)

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r",log=True)

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[12,50,57,22,35,15,36,52,59,45,59,56,34,24,43,50,20,57,24,55,14,33,53,49,34
    ,31,32,18,40,12,24,13,35,20,30,23,41,44,37,57,11,28,53,50,57,27,43,28,58,16]

l=[10,20,30,40,50,60]
plt.hist(no,color="y",bins=l,edgecolor="r",label="python")

plt.title("wscube")
plt.xlabel("python")
plt.ylabel("No.")

plt.axvline(45,color="g",label="line")

plt.legend()
plt.grid()
plt.show()
