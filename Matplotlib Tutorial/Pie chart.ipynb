# %%
import matplotlib.pyplot as plt


x = [10,20,30,40]
y = ["c","c++","java","python"]


plt.pie(x)


plt.show()

# %%
import matplotlib.pyplot as plt

x = [10,20,30,40]
y = ["c","c++","java","python"]
ex=[0.4,0.0,0.0,0.0]
c=["r","b","g","y"]

plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1,
       labeldistance=0.8,startangle=0,textprops={"fontsize":10},counterclock=False,
       wedgeprops={"linewidth":4})

plt.title("wscube tech")
plt.legend()
plt.show()

# %%
x = [10,20,30,40]
y = ["c","c++","java","python"]
ex=[0.4,0.0,0.0,0.0]
c=["r","b","g","y"]

plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1,
       labeldistance=0.8,startangle=0,textprops={"fontsize":10},counterclock=False,
       wedgeprops={"linewidth":4,"edgecolor":"m"},
       center=(3,6),rotatelabels=False)


plt.show()

# %%
plt.pie([1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","java","python"]


plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=1)
        

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","java","python"]

c=["r","b","g","y"]


plt.pie(x,labels=y,radius=1.5)
cr=plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca()

        

plt.show()
